# %% [markdown]
# Sitemap for project orgfiles
# ============================

# %% [markdown]
# -   [theindex.ipynb](./notebooks/theindex.ipynb)
# -   [readme.ipynb](./notebooks/readme.ipynb)
# -   [formatting-and-functions.ipynb](./notebooks/formatting-and-functions.ipynb)
# -   [fun-with-functions.ipynb](./notebooks/fun-with-functions.ipynb)
# -   [integrals.ipynb](./notebooks/integrals.ipynb)
# -   [tabular-formatting.ipynb](./notebooks/tabular-formatting.ipynb)
