# %% [markdown]
# Sitemap for project orgfiles
# ============================

# %% [markdown]
# -   [Index](theindex.md)
# -   [Practice problems](readme.md)
# -   [Practice with formatting strings and functions](formatting-and-functions.md)
# -   [fun-with-functions](fun-with-functions.md)
# -   [integrals](integrals.md)
# -   [tabular-formatting](tabular-formatting.md)

# %% [markdown]
# ## Solutions

# %% [markdown]
# [Click here for the solution](https://github.com/jkitchin/f21-06623/blob/master/practice/sitemap.ipynb)
