# %% [markdown]
# Formatting strings and functions
# ================================

# %% [markdown]
# ## formatting a float

# %% [markdown]
# Calculate the square root of three, and use that value to print a string that looks like:
#
# "The square root of 3 to 3 decimal places is 1.732."

# %%
# Out:
# The square root of 3 to 3 decimal places is 1.732.

# %% [markdown]
# ## Solutions

# %% [markdown]
# [Click here for the solution](https://github.com/jkitchin/f21-06623/blob/master/practice/formatting-and-functions.ipynb)
