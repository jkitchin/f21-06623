# %% [markdown]
# [Open in colab](https://colab.research.google.com/github/jkitchin/f21-06623/blob/master/practice/notebooks/equal-areas.ipynb)

# %% [markdown]
# ## Solutions

# %% [markdown]
# [Open in colab](https://colab.research.google.com/github/jkitchin/f21-06623/blob/master/practice/solutions/equal-areas.ipynb)
