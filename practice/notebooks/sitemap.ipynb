# %% [markdown]
# Sitemap for project notebooks
# =============================

# %% [markdown]
# [Open in colab](https://colab.research.google.com/github/jkitchin/f21-06623/blob/master/practice/notebooks/sitemap.ipynb)
#
# -   [theindex.ipynb](./theindex.ipynb) (nil)
# -   [readme.ipynb](./readme.ipynb) (((readme)))
# -   [formatting-and-functions.ipynb](./formatting-and-functions.ipynb) (nil)
# -   [tabular-formatting.ipynb](./tabular-formatting.ipynb) (nil)
# -   [fun-with-functions.ipynb](./fun-with-functions.ipynb) (nil)
# -   [integrals.ipynb](./integrals.ipynb) (nil)

# %% [markdown]
# ## Solutions

# %% [markdown]
# [Open in colab](https://colab.research.google.com/github/jkitchin/f21-06623/blob/master/practice/solutions/sitemap.ipynb)
